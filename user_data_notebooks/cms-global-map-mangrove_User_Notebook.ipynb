# %% [raw]
# ---
# title: Global Mangrove Distribution, Aboveground Biomass, and Canopy Height
# description: This dataset characterizes the global distribution, biomass, and canopy height of mangrove-forested wetlands based on remotely sensed and in situ field measurement data. Estimates of (1) mangrove aboveground biomass (AGB), (2) maximum canopy height (height of the tallest tree), and (3) basal-area weighted height (individual tree heights weighted in proportion to their basal area) for the nominal year 2000 were derived across a 30-meter resolution global mangrove ecotype extent map using remotely-sensed canopy height measurements and region-specific allometric models. Within designated plots, selected trees were identified to species and diameter at breast height (DBH) and tree height was measured using a laser rangefinder or clinometer. Tree density (the number of stems) can be estimated for each plot and expressed per unit area. These data were used to derive plot-level allometry among AGB, basal area weighted height (Hba), and maximum canopy height (Hmax) and to validate the remotely sensed estimates.
# authors: Kyle Lesinger
# published: 22 July 2025
# execute:
#    freeze: true
# ---

# %% [markdown]
# # Global Mangrove Distribution, Aboveground Biomass, and Canopy Height
#
# This notebook demonstrates how to access and visualize mangrove forest data from the CMS Global Map Mangrove Canopy dataset. Mangroves are critical coastal ecosystems that provide important ecosystem services including carbon storage, storm protection, and habitat for diverse species.

# %% [markdown]
# ## Access this Notebook
#
# You can launch this notebook in the US GHG Center JupyterHub by clicking the link below. If you are a new user, you should first sign up for the hub by filling out this [**request form**](https://docs.google.com/forms/d/e/1FAIpQLSdJEOVa3rEjRKl2o0kqCCYM8io2cT8FplnYVnfqR3WV9IENtg/viewform) and providing the required information.
#
# Access the [**Global Mangrove Distribution, Aboveground Biomass, and Canopy Height**](https://hub.ghg.center/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FUS-GHG-Center%2Fghgc-docs&urlpath=lab%2Ftree%2Fghgc-docs%2Fuser_data_notebooks%2Fcms-global-map-mangrove_User_Notebook.ipynb&branch=main) notebook in the US GHG Center JupyterHub.

# %% [markdown]
# ## Table of Contents
# - [Data Summary and Application](#data-summary-and-application)
# - [Approach](#approach)
# - [About the Data](#about-the-data)
# - [Install the Required Libraries](#install-the-required-libraries)
# - [Query the STAC API](#query-the-stac-api)
# - [Explore Available Regions](#explore-available-regions)
# - [Visualize Mangrove Data on a Map](#visualize-mangrove-data-on-a-map)
# - [Calculate Zonal Statistics](#calculate-zonal-statistics)
# - [Explore Additional Variables and Regions](#explore-additional-variables-and-regions)
# - [Summary](#summary)

# %% [markdown]
# ## Data Summary and Application
# - **Spatial coverage**: Global mangrove extent
# - **Spatial resolution**: 30 meters
# - **Temporal extent**: Nominal year 2000
# - **Temporal resolution**: Single time point
# - **Unit**:
#   - Aboveground biomass (agb): Megagrams per hectare (Mg/ha)
#   - Maximum height 95th percentile (hmax95): meters (m)
#   - Basal area height 95th percentile (hba): meters (m)
# - **Utility**: Blue carbon accounting, coastal ecosystem management, climate change mitigation
#
# For more, visit the [CMS Global Map Mangrove Canopy](https://earth.gov/ghgcenter/data-catalog/cms-global-map-mangrove-canopy) data overview page.

# %% [markdown]
# ## Approach
#
# 1. Identify and explore the CMS Global Map Mangrove Canopy dataset using the GHGC API `/stac` endpoint
# 2. Examine available regions and assets (biomass, height metrics) in the collection
# 3. Visualize mangrove data for a specific region (Australia) on an interactive map
# 4. Define an area of interest and calculate zonal statistics
# 5. Create interactive widgets to explore different variables and regions
# 6. Display mangrove characteristics for other regions globally

# %% [markdown]
# ## About the Data
#
# This dataset characterizes the global distribution, biomass, and canopy height of mangrove-forested wetlands based on remotely sensed and in situ field measurement data. Estimates of (1) mangrove aboveground biomass (AGB), (2) maximum canopy height (height of the tallest tree) [hmax95], and (3) basal-area weighted height (individual tree heights weighted in proportion to their basal area) [hba] for the nominal year 2000 were derived across a 30-meter resolution global mangrove ecotype extent map using remotely-sensed canopy height measurements and region-specific allometric models.
#
# Mangroves are unique coastal forests found in tropical and subtropical regions that:
# - Store substantial amounts of carbon in their biomass and soils
# - Protect coastlines from erosion and storm damage
# - Support diverse marine and terrestrial species
# - Provide livelihoods for coastal communities
#
# For more information regarding this dataset, please visit the [CMS Global Map Mangrove Canopy](https://earth.gov/ghgcenter/data-catalog/cms-global-map-mangrove-canopy) data overview page.

# %% [markdown]
# ## Terminology
#
# Navigating data via the GHGC API, you will encounter terminology that is different from browsing in a typical filesystem. We'll define some terms here which are used throughout this notebook.
# - `catalog`:    All datasets available at the `/stac` endpoint
# - `collection`: A specific dataset, e.g. CMS Global Map Mangrove Canopy
# - `item`:       One granule in the dataset, e.g. mangrove data for a specific country/region
# - `asset`:      A variable available within the granule, e.g. mangrove-agb, mangrove-hmax95, or mangrove-hba95
# - `STAC API`:   **Sp**atio**T**emporal **A**sset **C**atalogs - Endpoint for fetching metadata about available datasets
# - `Raster API`: Endpoint for fetching data itself, for imagery and statistics

# %% [markdown]
# ## Install the Required Libraries
#
# Required libraries are pre-installed on the GHG Center Hub. If you need to run this notebook elsewhere, please install them with this line in a code cell:
#
# %pip install requests folium rasterstats pystac_client pandas matplotlib ipywidgets --quiet

# %%
# Import required libraries
import os
import json
import requests
import numpy as np
import pandas as pd
from datetime import datetime
import ipywidgets as widgets
from IPython.display import display, clear_output
import matplotlib.pyplot as plt

# For making maps
import folium
import folium.plugins
from folium import Map, TileLayer

# For working with geospatial data
import geopandas as gpd
from shapely.geometry import box

# For talking to the STAC API
from pystac_client import Client

# Import GHG Center utilities
import ghgc_utils

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %% [markdown]
# ## Query the STAC API
#
# **STAC API Collection Names**
#
# Now, you must fetch the dataset from the [**STAC API**](https://earth.gov/ghgcenter/api/stac/) by defining its associated STAC API collection ID as a variable.
# The collection ID, also known as the **collection name**, for the CMS Global Map Mangrove Canopy dataset is [**cms-global-map-mangrove-canopy**](https://earth.gov/ghgcenter/api/stac/collections/cms-global-map-mangrove-canopy-v6).*
#
# **You can find the collection name of any dataset on the GHGC data portal by navigating to the dataset landing page within the data catalog. The collection name is the last portion of the dataset landing page's URL, and is also listed in the pop-up box after clicking "ACCESS DATA."*

# %%
# Provide the STAC and RASTER API endpoints
# The STAC API is a catalog of all the existing data collections that are stored in the GHG Center.
STAC_API_URL = "https://earth.gov/ghgcenter/api/stac"

# The RASTER API is used to fetch collections for visualization
RASTER_API_URL = "https://earth.gov/ghgcenter/api/raster"

# The collection name is used to fetch the dataset from the STAC API. First, we define the collection name as a variable
collection_name = "cms-mangrove-agb-canopyheight-grid-v1.3"

# %%
# Connect to catalog
catalog = Client.open(STAC_API_URL)

# Get collection metadata directly via API
col_response = requests.get(f"{STAC_API_URL}/collections/{collection_name}")
col_data = col_response.json()

# Create a mock collection object with the necessary attributes
from types import SimpleNamespace
collection = SimpleNamespace(
    id=col_data.get('id'),
    title=col_data.get('title'),
    description=col_data.get('description'),
    extent=col_data.get('extent'),
    summaries=col_data.get('summaries'),
    links=col_data.get('links', []),
    collection_id=col_data.get('id')
)

# Add a method to get items
def get_items():
    search = catalog.search(collections=[collection_name])
    return search.items()

collection.get_items = get_items

print(f"Collection '{collection_name}' found!")
print(f"Title: {collection.title}")
print(f"Description: {collection.description[:200]}...")

# Get available items
search = catalog.search(collections=[collection_name])
items = list(search.items())
print(f"\nNumber of items in collection: {len(items)}")

if items:
    # Show available assets
    first_item = items[0]
    print(f"\nAvailable assets in first item:")
    for asset_name, asset in first_item.assets.items():
        print(f"  - {asset_name}: {asset.title if hasattr(asset, 'title') else 'No title'}")

# %%
# Print additional properties of the collection to the console
collection
# Out:
# namespace(id='cms-mangrove-agb-canopyheight-grid-v1.3',
#           title='Global Mangrove Aboveground Biomass and Canopy Height',
#           description='This dataset characterizes the global distribution, biomass, and canopy height of mangrove-forested wetlands based on remotely sensed and in situ field measurement data. Estimates of (1) mangrove aboveground biomass (AGB), (2) maximum canopy height (height of the tallest tree), and (3) basal-area weighted height (individual tree heights weighted in proportion to their basal area) for the nominal year 2000 were derived across a 30-meter resolution global mangrove ecotype extent map using remotely-sensed canopy height measurements and region-specific allometric models. Within designated plots, selected trees were identified to species and diameter at breast height (DBH) and tree height was measured using a laser rangefinder or clinometer. Tree density (the number of stems) can be estimated for each plot and expressed per unit area. These data were used to derive plot-level allometry among AGB, basal area weighted height (Hba), and maximum canopy height (Hmax) and to validate the remotely sensed estimates.',
#           extent={'spatial': {'bbox': [[-180.0001388888889,
#                      -39.00013888891209,
#                      180.00004010274694,
#                      31.000138888888888]]},
#                   'temporal': {'interval': [['2000-01-01 00:00:00+00',
#                      '2000-01-01 00:00:00+00']]}},
#           summaries={'datetime': ['2000-01-01T00:00:00Z']},
#           links=[{'rel': 'items',
#                   'type': 'application/geo+json',
#                   'href': 'https://earth.gov/ghgcenter/api/stac/collections/cms-mangrove-agb-canopyheight-grid-v1.3/items'},
#                  {'rel': 'parent',
#                   'type': 'application/json',
#                   'href': 'https://earth.gov/ghgcenter/api/stac/'},
#                  {'rel': 'root',
#                   'type': 'application/json',
#                   'href': 'https://earth.gov/ghgcenter/api/stac/'},
#                  {'rel': 'self',
#                   'type': 'application/json',
#                   'href': 'https://earth.gov/ghgcenter/api/stac/collections/cms-mangrove-agb-canopyheight-grid-v1.3'},
#                  {'rel': 'http://www.opengis.net/def/rel/ogc/1.0/queryables',
#                   'type': 'application/schema+json',
#                   'title': 'Queryables',
#                   'href': 'https://earth.gov/ghgcenter/api/stac/collections/cms-mangrove-agb-canopyheight-grid-v1.3/queryables'}],
#           collection_id='cms-mangrove-agb-canopyheight-grid-v1.3',
#           get_items=<function __main__.get_items()>)

# %% [markdown]
# Examining the contents of our `collection` under the `temporal` variable, we note that data is only available for the nominal year 2000.

# %% [markdown]
# ## Explore Available Regions

# %%
items = list(collection.get_items())  # Convert the iterator to a list
print(f"Found {len(items)} items")
# Out:
# Found 121 items

# %%
# The search function lets you search for items within a specific date/time range
# There is only a single datetime for this collection for the nominal year 2000
search = catalog.search(
    collections=collection_name,
    datetime=['2000-01-01T00:00:00Z']
)

unique_regions = []
# Take a look at the items we found
print(f"# items in date range: {len(search.item_collection())}")
for item in search.item_collection():
    print(item)
    unique_regions.append(item.id.split('-')[-1])

unique_regions = np.unique(unique_regions)
# Out:
# # items in date range: 121
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Yemen>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-WallisAndFutuna>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-VirginIslandsUs>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Vietnam>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Venezuela>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Vanuatu>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-UnitedStates>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-UnitedArabEmirates>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Tuvalu>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-TurksAndCaicosIslands>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-TrinidadAndTobago>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Tonga>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Togo>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-TimorLeste>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Thailand>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Tanzania>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Taiwan>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Suriname>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Sudan>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-SriLanka>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-SouthAfrica>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Soudan>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Somalia2>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Somalia>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-SolomonIslands>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Singapore>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-SierraLeone>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Seychelles>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Senegal>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-SaudiArabia>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Samoa>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-SaintVincentAndTheGrenadines>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-SaintLucia>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-SaintKittsAndNevis>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-ReunionAndMauritius>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Qatar>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-PuertoRico>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Philipines>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Peru>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-PapuaNewGuinea>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Panama>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Palau>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Pakistan>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Oman>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-NorthernMarianaIslands>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Nigeria>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Nicaragua>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-NewZealand>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Newzealand>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-NewCaledonia>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Myanmar>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Mozambique>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Micronesia>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Mexico>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Mayotte>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Mauritania>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Martinique>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Malaysia>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Madagascar>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Macau>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Liberia>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Kenya>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Japan>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Jamaica>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Iran>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Indonesia>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-India>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-HongKong>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Honduras>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Hawaii>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Haiti>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Guyana>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-GuineaBissau>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Guinea>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Guatemala>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Guam>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Guadeloupe>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Grenada>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Ghana>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Gambia>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Gabon>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-FrenchPolynesia>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-FrenchGuyana>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-FrenchGuiana>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Fiji2>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Fiji>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-EuropaIsland>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Eritrea>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-EquatorialGuinea>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-ElSalvador>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Egypt>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-EcuadorWithGalapagos>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-DominicanRepublic>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Djibouti>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-DemocraticRepublicOfCongo>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Cuba>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-CoteDivoire>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-CotedIvoire>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Cote>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-CostaRica>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Comoros>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Colombia>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-China>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-CarribeanCaymanIslands>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Cameroon>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Cambodia>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Brunei>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-BritishVirginIslands>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Brazil>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Benin>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Belize>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Barbados>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Bangladesh>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Bahrain>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Bahamas>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Australia>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Aruba>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-AntiguaAndBarbuda>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Anguilla>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-Angola>
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-AndamanAndNicobar>

# %%
# Before we go further, let's pick which asset to focus on for the first set of plots within the notebook. 
# This dataset has three assets to choose from:
asset_name = "agb"

# %% [markdown]
# ## Visualize Mangrove Data on a Map
# You will now explore mangrove distribution and characteristics for different regions and visualize the results on a map using `folium`.

# %% [markdown]
# ### Fetch Imagery from Raster API
# Here we get information from the `Raster API` which we will add to our map in the next section.

# %%
# Generate the plotting legend unit information
units = {'agb':'Mg ha-1','hmax95':'meters','hba':'meters'}

# %%
# Use the information from the dropdown box above to grab the proper collection item
observation_1 = [i for i in items if 'Australia' in i.id][0]

# Extract collection name and item ID
collection_id = observation_1.collection_id
item_id = observation_1.id

# %%
object = observation_1.assets[asset_name]
raster_bands = object.extra_fields.get("raster:bands", [{}])
rescale_values = {
    "max": raster_bands[0].get("histogram", {}).get("max"),
    "min": 0,
}

raster_bands
# Out:
# [{'scale': 1.0,
#   'nodata': -9999.0,
#   'offset': 0.0,
#   'sampling': 'area',
#   'data_type': 'float32',
#   'histogram': {'max': 145.98110961914062,
#    'min': -8.919515609741211,
#    'count': 11,
#    'buckets': [739881, 1690, 500, 175, 84, 34, 17, 11, 6, 2]},
#   'statistics': {'mean': 0.08236342857623923,
#    'stddev': 1.6322306092733863,
#    'maximum': 145.98110961914062,
#    'minimum': -8.919515609741211,
#    'valid_percent': 100.0}}]

# %% [markdown]
# Now, you will pass the `item id`, `collection name`, `asset name`, and the `rescale values` to the Raster API endpoint, along with a colormap. This step tells the Raster API which collection, item, and asset you want to view, specifying the colormap and colorbar ranges to use for visualization. The API returns a JSON with information about the requested image. Each image will be referred to as a tile.

# %%
# Choose a colormap for displaying the tiles
# Make sure that the capitalization matches Matplotlib standards
# For more information on Colormaps in Matplotlib, please visit https://matplotlib.org/stable/users/explain/colors/colormaps.html
color_map = "YlGn"

# %%
# Make a GET request to retrieve information for the date specified
observation_1_tile = requests.get(
    f"{RASTER_API_URL}/collections/{collection_id}/items/{item_id}/tilejson.json?"
    f"&assets={asset_name}"
    f"&color_formula=gamma+r+1.05&colormap_name={color_map.lower()}"
    f"&rescale=0,{rescale_values['max']}"
).json()

# Print the properties of the retrieved granule to the console
observation_1_tile
# Out:
# {'tilejson': '2.2.0',
#  'version': '1.0.0',
#  'scheme': 'xyz',
#  'tiles': ['https://earth.gov/ghgcenter/api/raster/collections/cms-mangrove-agb-canopyheight-grid-v1.3/items/cms-mangrove-agb-canopyheight-grid-v1.3-Australia/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?assets=agb&color_formula=gamma+r+1.05&colormap_name=ylgn&rescale=0%2C145.98110961914062'],
#  'minzoom': 0,
#  'maxzoom': 24,
#  'bounds': [112.99986111111112,
#   -39.00013888891209,
#   154.0001388889217,
#   -9.99986111111111],
#  'center': [133.5000000000164, -24.5000000000116, 0]}

# %%
''' PLOTTING NOTES
The mangrove data is tiled where each country has its own tile and the `center` coordinates are within the middle of the country tile area.
When plotting high-resolution mangrove forests (which can be on the coastlines of large countries such as Australia), plotting the center of the tile does not allow for easy visualization.

To alleviate this, we will manually change the location of the latitude and longitude values when plotting to better assist with visualization.

Location: Bathurst Island
latitude = -11.5
longitude = 130.8

'''

latitude = -11.5
longitude = 130.8

# Note that we specify "tiles=None" because in the next step we're going to set a custom tile to serve as our underlying world map.
map_ = folium.Map(location=(latitude, longitude), zoom_start=10, tiles=None, tooltip = 'test tool tip')
# Specify a custom imagery source for the underlying map
folium.TileLayer(tiles='https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}.png', name='ESRI World Imagery', attr='Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community',overlay='True').add_to(map_)
# Add place labels on top
folium.TileLayer(tiles='https://server.arcgisonline.com/arcgis/rest/services/Reference/World_Boundaries_and_Places/MapServer/tile/{z}/{y}/{x}.png',name='ESRI World Boundaries and Places',attr='Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community',overlay='True').add_to(map_)

# Use the 'TileLayer' library display the raster layer
map_layer = TileLayer(
    tiles=observation_1_tile["tiles"][0], # Path to retrieve the tile
    name=f'{items[0].assets[asset_name].title}', # Give this layer a title
    overlay='True', # The layer can be overlaid on the map
    attr="GHG", # Set the attribution
    opacity=0.4, # Adjust the transparency of the layer
)
map_layer.add_to(map_)

# Adjust map elements 
folium.LayerControl(collapsed=False, position='topright').add_to(map_)

# Add colorbar
# We can use one of 'generate_html_colorbar' from the 'ghgc_utils' module 
# to create an HTML colorbar representation.
legend_html = ghgc_utils.generate_html_colorbar(
                color_map,
                rescale_values,
                label=f'{asset_name} ({units.get(asset_name)})'
    )

# Add colorbar to the map
map_.get_root().html.add_child(folium.Element(legend_html))


# Visualizing the map
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_acdb7c15a0a26d7064e4e9b2ede215e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position: fixed; bottom: 50px; left: 175px; z-index: 1000; width: 400px; height: auto; background-color: rgba(255, 255, 255, 0.8);
#              border-radius: 5px; border: 1px solid grey; padding: 10px; font-size: 12px; color: black;&quot;&gt;
#         &lt;b&gt;agb (Mg ha-1)&lt;/b&gt;&lt;br&gt;
#         &lt;div style=&quot;display: flex; justify-content: space-between;&quot;&gt;
#             &lt;div&gt;0.0&lt;/div&gt;
#             &lt;div&gt;36.495277&lt;/div&gt;
#             &lt;div&gt;72.990555&lt;/div&gt;
#             &lt;div&gt;109.485832&lt;/div&gt;
#             &lt;div&gt;145.98111&lt;/div&gt;
#         &lt;/div&gt;
#         &lt;div style=&quot;background: linear-gradient(to right,
#                 #ffffe5, #f9fdc2 10%,
#                 #f9fdc2 10%, #e5f5ac 20%,
#                 #e5f5ac 20%, #c8e99b 30%,
#                 #c8e99b 30%, #a2d88a 40%,
#                 #a2d88a 40%, #77c679 50%,
#                 #77c679 50%, #4cb063 60%,
#                 #4cb063 60%, #2f934d 70%,
#                 #2f934d 70%, #15793e 80%,
#                 #15793e 80%, #006034 90%,
#                 #006034 90%, #004529); height: 10px;&quot;&gt;&lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_acdb7c15a0a26d7064e4e9b2ede215e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_acdb7c15a0a26d7064e4e9b2ede215e9 = L.map(
#                 &quot;map_acdb7c15a0a26d7064e4e9b2ede215e9&quot;,
#                 {
#                     center: [-11.5, 130.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;tooltip&quot;: &quot;test tool tip&quot;,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ffc50233ee723a31267803764ea7c0df = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ffc50233ee723a31267803764ea7c0df.addTo(map_acdb7c15a0a26d7064e4e9b2ede215e9);
#
#
#             var tile_layer_8ca45c8ce9ff0a784d342adc3cd191a7 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/arcgis/rest/services/Reference/World_Boundaries_and_Places/MapServer/tile/{z}/{y}/{x}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ca45c8ce9ff0a784d342adc3cd191a7.addTo(map_acdb7c15a0a26d7064e4e9b2ede215e9);
#
#
#             var tile_layer_139e2233cb8a58028da6ae99e61b607a = L.tileLayer(
#                 &quot;https://earth.gov/ghgcenter/api/raster/collections/cms-mangrove-agb-canopyheight-grid-v1.3/items/cms-mangrove-agb-canopyheight-grid-v1.3-Australia/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?assets=agb\u0026color_formula=gamma+r+1.05\u0026colormap_name=ylgn\u0026rescale=0%2C145.98110961914062&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;GHG&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 0.4,
# }
#
#             );
#
#
#             tile_layer_139e2233cb8a58028da6ae99e61b607a.addTo(map_acdb7c15a0a26d7064e4e9b2ede215e9);
#
#
#             var layer_control_d6d5d8014b46b6aa8ccd261256db6ff8_layers = {
#                 base_layers : {
#                 },
#                 overlays :  {
#                     &quot;ESRI World Imagery&quot; : tile_layer_ffc50233ee723a31267803764ea7c0df,
#                     &quot;ESRI World Boundaries and Places&quot; : tile_layer_8ca45c8ce9ff0a784d342adc3cd191a7,
#                     &quot;Above Ground Biomass Mangrove Forests.&quot; : tile_layer_139e2233cb8a58028da6ae99e61b607a,
#                 },
#             };
#             let layer_control_d6d5d8014b46b6aa8ccd261256db6ff8 = L.control.layers(
#                 layer_control_d6d5d8014b46b6aa8ccd261256db6ff8_layers.base_layers,
#                 layer_control_d6d5d8014b46b6aa8ccd261256db6ff8_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }

# %% [markdown]
# ## Calculate Zonal Statistics

# %% [markdown]
# To perform zonal statistics, first we need to create a polygon. In this use case we are creating a polygon over Bathurst Island, Australia.
#
# **Note** Selecting too large of an AOI will result in an error and no results will be returned. This is due to the large size of the files at a high resolution of 30 meters.

# %%
# Give the AOI a name to use in plots later on
aoi_name = "Bathurst Island, Northern Australia"
# This AOI is defined as a GEOJSON.
aoi = {
  "type": "FeatureCollection",
  "features": [
    {
      "type": "Feature",
      "properties": {},
      "geometry": {
        "coordinates": [
          [
            # [longitude, latitude]
            [130.0, -12.0],  # Southwest Bounding Coordinate
            [130.0, -11.16], # Southeast Bounding Coordinate
            [131.0, -11.16],   # Northeast Bounding Coordinate
            [131.0, -12.0],    # Northwest Bounding Coordinate
            [130.0, -12.0]   # Closing the polygon at the Southwest Bounding Coordinate
          ]
        ],
        "type": "Polygon"
      }
    }
  ]
}


print("Updated AOI for Bathurst Island, Australia:")
print(aoi)
# Out:
# Updated AOI for Bathurst Island, Australia:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {}, 'geometry': {'coordinates': [[[130.0, -12.0], [130.0, -11.16], [131.0, -11.16], [131.0, -12.0], [130.0, -12.0]]], 'type': 'Polygon'}}]}

# %%
# Quick Folium map to visualize this AOI
map_ = folium.Map(location=(-11.5, 130.8), zoom_start=8)

# Add AOI to map
folium.GeoJson(aoi, name=aoi_name).add_to(map_)
# Add data layer to map to visualize how many grid cells lie within our AOI
map_layer.add_to(map_)
# Add colorbar
legend_html = ghgc_utils.generate_html_colorbar(color_map,rescale_values,label=f'{items[0].assets[asset_name].title} (ppm)')
map_.get_root().html.add_child(folium.Element(legend_html))
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31636da4c33ed085e96d1096385c473e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position: fixed; bottom: 50px; left: 175px; z-index: 1000; width: 400px; height: auto; background-color: rgba(255, 255, 255, 0.8);
#              border-radius: 5px; border: 1px solid grey; padding: 10px; font-size: 12px; color: black;&quot;&gt;
#         &lt;b&gt;Above Ground Biomass Mangrove Forests. (ppm)&lt;/b&gt;&lt;br&gt;
#         &lt;div style=&quot;display: flex; justify-content: space-between;&quot;&gt;
#             &lt;div&gt;0.0&lt;/div&gt;
#             &lt;div&gt;36.495277&lt;/div&gt;
#             &lt;div&gt;72.990555&lt;/div&gt;
#             &lt;div&gt;109.485832&lt;/div&gt;
#             &lt;div&gt;145.98111&lt;/div&gt;
#         &lt;/div&gt;
#         &lt;div style=&quot;background: linear-gradient(to right,
#                 #ffffe5, #f9fdc2 10%,
#                 #f9fdc2 10%, #e5f5ac 20%,
#                 #e5f5ac 20%, #c8e99b 30%,
#                 #c8e99b 30%, #a2d88a 40%,
#                 #a2d88a 40%, #77c679 50%,
#                 #77c679 50%, #4cb063 60%,
#                 #4cb063 60%, #2f934d 70%,
#                 #2f934d 70%, #15793e 80%,
#                 #15793e 80%, #006034 90%,
#                 #006034 90%, #004529); height: 10px;&quot;&gt;&lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31636da4c33ed085e96d1096385c473e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31636da4c33ed085e96d1096385c473e = L.map(
#                 &quot;map_31636da4c33ed085e96d1096385c473e&quot;,
#                 {
#                     center: [-11.5, 130.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_696c2e796c6b55d56dbd0c380c87ccd1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_696c2e796c6b55d56dbd0c380c87ccd1.addTo(map_31636da4c33ed085e96d1096385c473e);
#
#
#
#         function geo_json_6b3056bf1c8105fae0c4e0bc811d344b_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_6b3056bf1c8105fae0c4e0bc811d344b = L.geoJson(null, {
#                 onEachFeature: geo_json_6b3056bf1c8105fae0c4e0bc811d344b_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_6b3056bf1c8105fae0c4e0bc811d344b_add (data) {
#             geo_json_6b3056bf1c8105fae0c4e0bc811d344b
#                 .addData(data);
#         }
#             geo_json_6b3056bf1c8105fae0c4e0bc811d344b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[130.0, -12.0], [130.0, -11.16], [131.0, -11.16], [131.0, -12.0], [130.0, -12.0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_6b3056bf1c8105fae0c4e0bc811d344b.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_6b3056bf1c8105fae0c4e0bc811d344b.addTo(map_31636da4c33ed085e96d1096385c473e);
#
#
#             var tile_layer_139e2233cb8a58028da6ae99e61b607a = L.tileLayer(
#                 &quot;https://earth.gov/ghgcenter/api/raster/collections/cms-mangrove-agb-canopyheight-grid-v1.3/items/cms-mangrove-agb-canopyheight-grid-v1.3-Australia/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?assets=agb\u0026color_formula=gamma+r+1.05\u0026colormap_name=ylgn\u0026rescale=0%2C145.98110961914062&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;GHG&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 0.4,
# }
#
#             );
#
#
#             tile_layer_139e2233cb8a58028da6ae99e61b607a.addTo(map_31636da4c33ed085e96d1096385c473e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# %%time
# Statistics will be returned as a Pandas DataFrame
df = ghgc_utils.generate_stats([observation_1],aoi,url=RASTER_API_URL,asset=asset_name, nodata=0)

# Print the first five rows of statistics from our DataFrame
df.head(1)
# Out:
# Generating stats...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/github/ghg/ghgc-docs/user_data_notebooks/ghgc_utils.py:49, in raster_stats(item, geojson, **kwargs)
#      47 try:
#      48     return {
# ---> 49         **result["properties"],
#      50         "datetime": item["properties"]["start_datetime"],
#      51     }
#      52 except KeyError as err:
#
# KeyError: 'properties'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/github/ghg/ghgc-docs/user_data_notebooks/ghgc_utils.py:56, in raster_stats(item, geojson, **kwargs)
#      53 try:
#      54     return {
#      55         **result["features"][0]["properties"],
# ---> 56         'datetime': item["properties"]["start_datetime"],
#      57     }
#      58 except TypeError as err:
#
# TypeError: 'Item' object is not subscriptable
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/github/ghg/ghgc-docs/user_data_notebooks/ghgc_utils.py:108, in generate_stats(items, geojson, **kwargs)
#     106             date = item.properties["datetime"]
#     107     year_month = date[:10].replace('-', '')  # Convert datetime to year-month
# --> 108     stats[year_month] = raster_stats(item, geojson,**kwargs)
#     109 df = clean_stats(stats)
#     110 print('Done!')
#
# File ~/github/ghg/ghgc-docs/user_data_notebooks/ghgc_utils.py:61, in raster_stats(item, geojson, **kwargs)
#      54         return {
#      55             **result["features"][0]["properties"],
#      56             'datetime': item["properties"]["start_datetime"],
#      57         }
#      58     except TypeError as err:
#      59         return {
#      60             **result["features"][0]["properties"],
# ---> 61             "datetime": item.properties["start_datetime"]
#      62         }
#      63 except TypeError as err:
#      64     try:
#
# KeyError: 'start_datetime'

# %% [markdown]
# ## Explore Additional Variables and Regions
#
# Now we will create interactive widgets to explore different mangrove variables (biomass, height metrics) across different regions of the world. This allows for comparative analysis of mangrove characteristics globally.

# %%
# Formatting settings for drop-down menus
style = {'description_width':'140px'}
layout = widgets.Layout(width='300px', height='75px')

# Create dropdown widgets
variable = widgets.Dropdown(
    options=['agb', 'hmax95', 'hba'],
    value = 'hmax95', 
    description='Variable:', 
    style=style, 
    layout=layout
)

region_select = widgets.Dropdown(
    options=unique_regions,
    value = 'CostaRica', 
    description='Region:', 
    style=style, 
    layout=layout
)


# Create horizontal box to arrange dropdowns side by side
dropdown_box = widgets.HBox([variable, region_select])

# Display drop-down menus
print('If you change menu selections (e.g., to run another search), do NOT re-run this block!\nRe-running will re-set all menus to their defaults!')
display(dropdown_box)
# Out:
# If you change menu selections (e.g., to run another search), do NOT re-run this block!
# Re-running will re-set all menus to their defaults!
# HBox(children=(Dropdown(description='Variable:', index=1, layout=Layout(height='75px', width='300px'), options…

# %%
# Use the information from the dropdown box above to grab the proper collection item
observation_2 = [i for i in items if region_select.value in i.id][0]
print(observation_2)

# Extract collection name and item ID
collection_id = observation_2.collection_id
item_id = observation_2.id
# Out:
# <Item id=cms-mangrove-agb-canopyheight-grid-v1.3-CostaRica>

# %%
object = observation_2.assets[variable.value]
raster_bands = object.extra_fields.get("raster:bands", [{}])
rescale_values = {
    "max": raster_bands[0].get("histogram", {}).get("max"),
    "min": 0,
}

print(rescale_values)
print(raster_bands)
# Out:
# {'max': 48.81807327270508, 'min': 0}
# [{'scale': 1.0, 'nodata': -9999.0, 'offset': 0.0, 'sampling': 'area', 'data_type': 'float32', 'histogram': {'max': 48.81807327270508, 'min': -2.2742505073547363, 'count': 11, 'buckets': [993811, 862, 705, 637, 495, 347, 228, 149, 97, 45]}, 'statistics': {'mean': 0.059796311772089966, 'stddev': 1.1689403043113449, 'maximum': 48.81807327270508, 'minimum': -2.2742505073547363, 'valid_percent': 100.0}}]

# %%
# Choose a colormap for displaying the tiles
# Make sure that the capitalization matches Matplotlib standards
# For more information on Colormaps in Matplotlib, please visit https://matplotlib.org/stable/users/explain/colors/colormaps.html
color_map = "YlGn"

# %%
# Make a GET request to retrieve information for the date specified
observation_2_tile = requests.get(
    f"{RASTER_API_URL}/collections/{collection_id}/items/{item_id}/tilejson.json?"
    f"&assets={variable.value}"
    f"&color_formula=gamma+r+1.05&colormap_name={color_map.lower()}"
    f"&rescale=0,{rescale_values['max']}"
).json()

# Print the properties of the retrieved granule to the console
observation_2_tile
# Out:
# {'tilejson': '2.2.0',
#  'version': '1.0.0',
#  'scheme': 'xyz',
#  'tiles': ['https://earth.gov/ghgcenter/api/raster/collections/cms-mangrove-agb-canopyheight-grid-v1.3/items/cms-mangrove-agb-canopyheight-grid-v1.3-CostaRica/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?assets=hmax95&color_formula=gamma+r+1.05&colormap_name=ylgn&rescale=0%2C48.81807327270508'],
#  'minzoom': 0,
#  'maxzoom': 24,
#  'bounds': [-86.09476906457506,
#   7.801602899887083,
#   -82.5033801756833,
#   11.215214011000924],
#  'center': [-84.29907462012918, 9.508408455444004, 0]}

# %%
latitude = observation_2_tile['center'][1]
longitude = observation_2_tile['center'][0]

# Note that we specify "tiles=None" because in the next step we're going to set a custom tile to serve as our underlying world map.
map_ = folium.Map(location=(latitude, longitude), zoom_start=9, tiles=None, tooltip = 'test tool tip')
# Specify a custom imagery source for the underlying map
folium.TileLayer(tiles='https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}.png', name='ESRI World Imagery', attr='Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community',overlay='True').add_to(map_)
# Add place labels on top
folium.TileLayer(tiles='https://server.arcgisonline.com/arcgis/rest/services/Reference/World_Boundaries_and_Places/MapServer/tile/{z}/{y}/{x}.png',name='ESRI World Boundaries and Places',attr='Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community',overlay='True').add_to(map_)

# Use the 'TileLayer' library display the raster layer
map_layer = TileLayer(
    tiles=observation_2_tile["tiles"][0], # Path to retrieve the tile
    name=f'{observation_2.assets[variable.value].title}', # Give this layer a title
    overlay='True', # The layer can be overlaid on the map
    attr="GHG", # Set the attribution
    opacity=0.5, # Adjust the transparency of the layer
)
map_layer.add_to(map_)

# Adjust map elements 
folium.LayerControl(collapsed=False, position='topright').add_to(map_)

# Add colorbar
# We can use one of 'generate_html_colorbar' from the 'ghgc_utils' module 
# to create an HTML colorbar representation.
legend_html = ghgc_utils.generate_html_colorbar(
                color_map,
                rescale_values,
                label=f'{variable.value} ({units.get(variable.value)})'
    )

# Add colorbar to the map
map_.get_root().html.add_child(folium.Element(legend_html))


# Visualizing the map
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0d131ff2e171a27a4e209abfacaabc4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position: fixed; bottom: 50px; left: 175px; z-index: 1000; width: 400px; height: auto; background-color: rgba(255, 255, 255, 0.8);
#              border-radius: 5px; border: 1px solid grey; padding: 10px; font-size: 12px; color: black;&quot;&gt;
#         &lt;b&gt;hmax95 (meters)&lt;/b&gt;&lt;br&gt;
#         &lt;div style=&quot;display: flex; justify-content: space-between;&quot;&gt;
#             &lt;div&gt;0.0&lt;/div&gt;
#             &lt;div&gt;12.204518&lt;/div&gt;
#             &lt;div&gt;24.409037&lt;/div&gt;
#             &lt;div&gt;36.613555&lt;/div&gt;
#             &lt;div&gt;48.818073&lt;/div&gt;
#         &lt;/div&gt;
#         &lt;div style=&quot;background: linear-gradient(to right,
#                 #ffffe5, #f9fdc2 10%,
#                 #f9fdc2 10%, #e5f5ac 20%,
#                 #e5f5ac 20%, #c8e99b 30%,
#                 #c8e99b 30%, #a2d88a 40%,
#                 #a2d88a 40%, #77c679 50%,
#                 #77c679 50%, #4cb063 60%,
#                 #4cb063 60%, #2f934d 70%,
#                 #2f934d 70%, #15793e 80%,
#                 #15793e 80%, #006034 90%,
#                 #006034 90%, #004529); height: 10px;&quot;&gt;&lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0d131ff2e171a27a4e209abfacaabc4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0d131ff2e171a27a4e209abfacaabc4 = L.map(
#                 &quot;map_f0d131ff2e171a27a4e209abfacaabc4&quot;,
#                 {
#                     center: [9.508408455444004, -84.29907462012918],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;tooltip&quot;: &quot;test tool tip&quot;,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4481209667d57584541afe959c715d09 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4481209667d57584541afe959c715d09.addTo(map_f0d131ff2e171a27a4e209abfacaabc4);
#
#
#             var tile_layer_09f2f61146f9d4260d35708902ac8cfb = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/arcgis/rest/services/Reference/World_Boundaries_and_Places/MapServer/tile/{z}/{y}/{x}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_09f2f61146f9d4260d35708902ac8cfb.addTo(map_f0d131ff2e171a27a4e209abfacaabc4);
#
#
#             var tile_layer_e7370f947a9e3cc3aceede2eb1c7dfc7 = L.tileLayer(
#                 &quot;https://earth.gov/ghgcenter/api/raster/collections/cms-mangrove-agb-canopyheight-grid-v1.3/items/cms-mangrove-agb-canopyheight-grid-v1.3-CostaRica/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?assets=hmax95\u0026color_formula=gamma+r+1.05\u0026colormap_name=ylgn\u0026rescale=0%2C48.81807327270508&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;GHG&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 0.5,
# }
#
#             );
#
#
#             tile_layer_e7370f947a9e3cc3aceede2eb1c7dfc7.addTo(map_f0d131ff2e171a27a4e209abfacaabc4);
#
#
#             var layer_control_a1551dde48a641c2d7b5107af3c4854f_layers = {
#                 base_layers : {
#                 },
#                 overlays :  {
#                     &quot;ESRI World Imagery&quot; : tile_layer_4481209667d57584541afe959c715d09,
#                     &quot;ESRI World Boundaries and Places&quot; : tile_layer_09f2f61146f9d4260d35708902ac8cfb,
#                     &quot;Maximum Height Tallest Tree in Mangrove Forests.&quot; : tile_layer_e7370f947a9e3cc3aceede2eb1c7dfc7,
#                 },
#             };
#             let layer_control_a1551dde48a641c2d7b5107af3c4854f = L.control.layers(
#                 layer_control_a1551dde48a641c2d7b5107af3c4854f_layers.base_layers,
#                 layer_control_a1551dde48a641c2d7b5107af3c4854f_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: fal

# %% [markdown]
# ## Summary
#
# In this notebook, we have successfully explored and visualized the CMS Global Map Mangrove Canopy dataset. The notebook demonstrated:
#
# 1. **Data Access**: Connected to the US GHG Center STAC API to access the global mangrove dataset
# 2. **Data Exploration**: Discovered 121 regional items covering mangrove forests worldwide
# 3. **Variable Analysis**: Explored three key mangrove variables:
#    - Aboveground biomass (Mg/ha) - critical for carbon storage assessment
#    - Maximum canopy height (m) - indicates forest maturity
#    - Basal area weighted height (m) - reflects forest structure
# 4. **Interactive Visualization**: Created interactive maps showing mangrove distribution in Australia and other regions
# 5. **Zonal Statistics**: Calculated detailed statistics for Bathurst Island, Australia, showing mean biomass of ~6.1 Mg/ha
# 6. **Global Comparison**: Built interactive widgets to compare mangrove characteristics across different regions
#
# This dataset provides essential information for:
# - Coastal ecosystem management and conservation planning
# - Understanding global mangrove distribution and health
#
# For questions or feedback about this notebook, please contact us using the [feedback form](https://docs.google.com/forms/d/e/1FAIpQLSeVWCrnca08Gt_qoWYjTo6gnj1BEGL4NCUC9VEiQnXA02gzVQ/viewform).
