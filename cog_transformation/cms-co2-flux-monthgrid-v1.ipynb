# %%
import os
import xarray
import re
import pandas as pd
import json
import tempfile
import boto3
from datetime import datetime
import s3fs
from dateutil.relativedelta import relativedelta


s3_bucket = "ghgc-data-store-dev"
source_folder = 'delivery/cms-co2-flux-monthgrid-v1'
target_folder = 'delivery/cms-co2-flux-monthgrid-v1-cogs'
session = boto3.Session(profile_name="veda-smce-mfa")

s3_client = session.client("s3")
files_processed = pd.DataFrame(columns=["file_name", "COGs_created"])
fs = s3fs.S3FileSystem(profile="veda-smce-mfa", anon=False)
start_date = '2010-01-01'

# File contains monthly data for each year from 2010 to 2022

# %%
def get_all_s3_keys(bucket, source_folder):
    """Get a list of all keys in an S3 bucket."""
    keys = []

    kwargs = {"Bucket": bucket, "Prefix": f"{source_folder}/"}
    while True:
        resp = s3_client.list_objects_v2(**kwargs)
        for obj in resp["Contents"]:
            if obj["Key"].endswith(".nc") and "historical" not in obj["Key"]:
                keys.append(obj["Key"])

        try:
            kwargs["ContinuationToken"] = resp["NextContinuationToken"]
        except KeyError:
            break

    return keys


keys = get_all_s3_keys(s3_bucket, source_folder)

# %%
for key in keys:
    file_obj = fs.open(f"s3://{s3_bucket}/{key}")
    xds = xarray.open_dataset(file_obj, engine="scipy", decode_times=False)
    xds = xds.assign_coords(longitude=(((xds.longitude + 180) % 360) - 180)).sortby("longitude")
    variables = [var for var in xds.data_vars]
    # filename_elements = filename.split("_")
    for time_increment in xds.indexes['time']:
        for var in variables[:1]:
            filename = file_obj.full_name.split("/")[-1]
            filename_elements = re.split("[_ .]", filename)
            data = getattr(xds.isel(time=time_increment), var)
            data = data.isel(lat=slice(None, None, -1))
            data.rio.set_spatial_dims("lon", "lat", inplace=True)
            data.rio.write_crs("epsg:4326", inplace=True)
            data.rio.write_nodata(-9999, inplace=True)
            date = start_time + relativedelta(months=+time_increment)

            filename_elements[-1] = date
            filename_elements.append(var)
            cog_filename = "_".join(filename_elements)
            # add extension
            cog_filename = f"{cog_filename}.tif"
            # cog_filepath = "/".join(key.split("/")[1:-1])

            with tempfile.NamedTemporaryFile() as temp_file:
                data.rio.to_raster(temp_file.name, driver="COG", compress="DEFLATE")
                # s3_client.upload_file(
                #     Filename=temp_file.name,
                #     Bucket=cog_data_s3_bucket,
                #     Key=f"climdex/tmaxXF/ACCESS-CM2/{cog_filename}",
                # )

            files_processed = files_processed._append(
                {
                    "file_name": key,
                    "COGs_created": f"climdex/tmaxXF/ACCESS-CM2/{cog_filename}",
                },
                ignore_index=True,
            )

            print(f"Generated and saved COG: {cog_filename}")

files_processed.to_csv(
f"s3://{cog_data_s3_bucket}/CMIP6/files_converted.csv",
)
print("Done generating COGs")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 11
#       9 filename = file_obj.full_name.split("/")[-1]
#      10 filename_elements = re.split("[_ .]", filename)
# ---> 11 data = getattr(xds.isel(time=time_increment), var)
#      12 data = data.isel(lat=slice(None, None, -1))
#      13 data.rio.set_spatial_dims("lon", "lat", inplace=True)
#
# File ~/miniconda3/envs/cmip6/lib/python3.9/site-packages/xarray/core/dataset.py:2434, in Dataset.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    2432 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "isel")
#    2433 if any(is_fancy_indexer(idx) for idx in indexers.values()):
# -> 2434     return self._isel_fancy(indexers, drop=drop, missing_dims=missing_dims)
#    2436 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
# ...

# %%
xds

# %%
xds = xarray.open_dataset('../../Downloads/CMSFluxFossilFuelPrior201001_202212_v3.nc', engine = 'netcdf4',decode_times=False)
xds = xds.assign_coords(longitude=(((xds.longitude + 180) % 360) - 180)).sortby("longitude")
xds

# %%
xds.longitude

# %%
xds.indexes['time']
