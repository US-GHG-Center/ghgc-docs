# %% [raw]
# ---
# title: CASA-GFED3 Land Carbon Flux
# description: Documentation of data transformation
# author: Vishal Gaur
# date: August 30, 2023
# execute:
#   freeze: true
# ---

# %% [markdown]
# Code used to transform CASA-GFED3 Land Carbon Flux data from netcdf to Cloud Optimized Geotiff.

# %%
import os
import xarray
import re
import pandas as pd
import json
import tempfile
import boto3

# %%
session = boto3.session.Session(profile_name='veda-smce-mfa')
s3_client = session.client("s3")
bucket_name = "ghgc-data-store-dev"
date_fmt = "%Y%m"

files_processed = pd.DataFrame(columns=["file_name", "COGs_created"])
for name in os.listdir("../data/casa-gfed"):
    xds = xarray.open_dataset(
        f"../data/casa-gfed/{name}",
        engine="netcdf4",
    )
    xds = xds.assign_coords(
        longitude=(((xds.longitude + 180) % 360) - 180)
    ).sortby("longitude")
    variable = [var for var in xds.data_vars]

    for time_increment in range(0, len(xds.time)):
        for var in variable[:-1]:
            filename = name.split("/ ")[-1]
            filename_elements = re.split("[_ .]", filename)
            data = getattr(xds.isel(time=time_increment), var)
            data = data.isel(latitude=slice(None, None, -1))
            data.rio.set_spatial_dims("longitude", "latitude", inplace=True)
            data.rio.write_crs("epsg:4326", inplace=True)
            data.rio.write_nodata(-9999, inplace=True)

            date = data.time.dt.strftime(date_fmt).item(0)
            # # insert date of generated COG into filename
            filename_elements.pop()
            filename_elements[-1] = date
            filename_elements.insert(2, var)
            cog_filename = "_".join(filename_elements)
            # # add extension
            cog_filename = f"{cog_filename}.tif"

            with tempfile.NamedTemporaryFile() as temp_file:
                data.rio.to_raster(
                    temp_file.name,
                    driver="COG",
                )
                s3_client.upload_file(
                    Filename=temp_file.name,
                    Bucket=bucket_name,
                    Key=f"casa-gfed-carbon-flux/{cog_filename}",
                )

            files_processed = files_processed._append(
                {"file_name": name, "COGs_created": cog_filename},
                ignore_index=True,
            )

            print(f"Generated and saved COG: {cog_filename}")

with tempfile.NamedTemporaryFile(mode="w+") as fp:
    json.dump(xds.attrs, fp)
    json.dump({"data_dimensions": dict(xds.dims)}, fp)
    json.dump({"data_variables": list(xds.data_vars)}, fp)
    fp.flush()

    s3_client.upload_file(
        Filename=fp.name,
        Bucket=bucket_name,
        Key="GEOS-Carbs/metadata.json",
    )
files_processed.to_csv(
    f"s3://{bucket_name}/GEOS-Carbs/files_converted.csv",
)
print("Done generating COGs")
# Out:
# ---------------------------------------------------------------------------
# TokenRetrievalError                       Traceback (most recent call last)
# Cell In[3], line 37
#      34 cog_filename = f"{cog_filename}.tif"
#      36 with tempfile.NamedTemporaryFile() as temp_file:
# ---> 37     data.rio.to_raster(
#      38         temp_file.name,
#      39         driver="COG",
#      40     )
#      41     s3_client.upload_file(
#      42         Filename=temp_file.name,
#      43         Bucket=bucket_name,
#      44         Key=f"casa-gfed-carbon-flux/{cog_filename}",
#      45     )
#      47 files_processed = files_processed._append(
#      48     {"file_name": name, "COGs_created": cog_filename},
#      49     ignore_index=True,
#      50 )
#
# File ~/miniconda3/envs/cmip6/lib/python3.9/site-packages/rioxarray/raster_array.py:1119, in RasterArray.to_raster(self, raster_path, driver, dtype, tags, windowed, recalc_transform, lock, compute, **profile_kwargs)
#    1100 out_profile = {
#    1101     key: value
#    1102     for key, value in out_profile.items()
#    (...)
#    1113     )
#    1114 }
#    1115 rio_nodata = (
#    1116     self.encoded_nodata if self.encoded_nodata is not None else self.nodata
#    1117 )
# -> 1119 return RasterioWriter(raster_path=raster_path).to_raster(
#    1120     xarray_dataarray=self._obj,
#    1121     tags=tags,
#    1122     driver=driver,
#    1123     height=int(self.height),
#    1124     width=int(self.width),
#    1125     count=int(self.count),
#    1126     dtype=dtype,
#    1127     crs=self.crs,
#    1128     transform=self.transform(recalc=recalc_transform),
#    1129     gcps=self.get_gcps(),
#    1130     nodata=rio_nodata,
#    1131     windowed=windowed,
#    1132     lock=lock,
#    1133     compute=compute,
#    1134     **out_profile,
#    1135 )
#
# File ~/miniconda3/envs/cmip6/lib/python3.9/site-packages/rioxarray/raster_writer.py:273, in RasterioWriter.to_raster(self, xarray_dataarray, tags, windowed, lock, compute, **kwargs)
#     267 if kwargs["nodata"] is not None:
#     268     # Ensure dtype of output data matches the expected dtype.
#     269     # This check is added here as the dtype of the data is
#     270     # converted right before writing.
#     271     kwargs["nodata"] = _ensure_nodata_dtype(kwargs["nodata"], numpy_dtype)
# --> 273 with rasterio.open(self.raster_path, "w", **kwargs) as rds:
#     274     _write_metatata_to_raster(rds, xarray_dataarray, tags)
#     275     if not (lock and is_dask_collection(xarray_dataarray.data)):
#     276         # write data to raster immmediately if not dask array
#
# File rasterio/_base.pyx:443, in rasterio._base.DatasetBase.__enter__()
#
# File ~/miniconda3/envs/cmip6/lib/python3.9/site-packages/rasterio/env.py:389, in env_ctx_if_needed()
#     387     return NullContextManager()
#     388 else:
# --> 389     return Env.from_defaults()
#
# File ~/miniconda3/envs/cmip6/lib/python3.9/site-packages/rasterio/env.py:236, in Env.from_defaults(cls, *args, **kwargs)
#     234 options = Env.default_options()
#     235 options.update(**kwargs)
# --> 236 return Env(*args, **options)
#
# File ~/miniconda3/envs/cmip6/lib/python3.9/site-packages/rasterio/env.py:206, in Env.__init__(self, session, aws_unsigned, profile_name, session_class, **options)
#     197     self.session = Session.aws_or_dummy(
#     198         aws_access_key_id=aws_access_key_id,
#     199         aws_secret_access_key=aws_secret_access_key,
#    (...)
#     202         profile_name=profile_name,
#     203         aws_unsigned=aws_unsigned)
#     205 elif 'AWS_ACCESS_KEY_ID' in os.environ and 'AWS_SECRET_ACCESS_KEY' in os.environ:
# --> 206     self.session = Session.from_environ()
#     208 else:
#     209     self.session = DummySession()
#
# File ~/miniconda3/envs/cmip6/lib/python3.9/site-packages/rasterio/session.py:192, in Session.from_environ(*args, **kwargs)
#     190 try:
#     191     session = Session.aws_or_dummy(*args, **kwargs)
# --> 192     session.credentials
#     193 except RuntimeError as exc:
#     194     log.warning("Credentials in environment have expired. Creating a DummySession.")
#
# File ~/miniconda3/envs/cmip6/lib/python3.9/site-packages/rasterio/session.py:322, in AWSSession.credentials(self)
#     320 res = {}
#     321 if self._creds:  # pragma: no branch
# --> 322     frozen_creds = self._creds.get_frozen_credentials()
#     323     if frozen_creds.access_key:  # pragma: no branch
#     324         res['aws_access_key_id'] = frozen_creds.access_key
#
# File ~/miniconda3/envs/cmip6/lib/python3.9/site-packages/botocore/credentials.py:610, in RefreshableCredentials.get_frozen_credentials(self)
#     576 def get_frozen_credentials(self):
#     577     """Return immutable credentials.
#     578
#     579     The ``access_key``, ``secret_key``, and ``token`` properties
#    (...)
#     608
#     609     """
# --> 610     self._refresh()
#     611     return self._frozen_credentials
#
# File ~/miniconda3/envs/cmip6/lib/python3.9/site-packages/botocore/credentials.py:498, in RefreshableCredentials._refresh(self)
#     494         return
#     495     is_mandatory_refresh = self.refresh_needed(
#     496         self._mandatory_refresh_timeout
#     497     )
# --> 498     self._protected_refresh(is_mandatory=is_mandatory_refresh)
#     499     return
#     500 finally:
#
# File ~/miniconda3/envs/cmip6/lib/python3.9/site-packages/botocore/credentials.py:514, in RefreshableCredentials._protected_refresh(self, is_mandatory)
#     510 def _protected_refresh(self, is_mandatory):
#     511     # precondition: this method should only be called if you've acquired
#     512     # the self._refresh_lock.
#     513     try:
# --> 514         metadata = self._refresh_using()
#     515     except Exception:
#     516         period_name = 'mandatory' if is_mandatory else 'advisory'
#
# File ~/miniconda3/envs/cmip6/lib/python3.9/site-packages/botocore/credentials.py:661, in CachedCredentialFetcher.fetch_credentials(self)
#     660 def fetch_credentials(self):
# --> 661     return self._get_cached_credentials()
#
# File ~/miniconda3/envs/cmip6/lib/python3.9/site-packages/botocore/credentials.py:671, in CachedCredentialFetcher._get_cached_credentials(self)
#     669 response = self._load_from_cache()
#     670 if response is None:
# --> 671     response = self._get_credentials()
#     672     self._write_to_cache(response)
#     673 else:
#
# File ~/miniconda3/envs/cmip6/lib/python3.9/site-packages/botocore/credentials.py:2115, in SSOCredentialFetcher._get_credentials(self)
#    2113 if self._token_provider:
#    2114     initial_token_data = self._token_provider.load_token()
# -> 2115     token = initial_token_data.get_frozen_token().token
#    2116 else:
#    2117     token = self._token_loader(self._start_url)['accessToken']
#
# File ~/miniconda3/envs/cmip6/lib/python3.9/site-packages/botocore/tokens.py:82, in DeferredRefreshableToken.get_frozen_token(self)
#      81 def get_frozen_token(self):
# ---> 82     self._refresh()
#      83     return self._frozen_token
#
# File ~/miniconda3/envs/cmip6/lib/python3.9/site-packages/botocore/tokens.py:95, in DeferredRefreshableToken._refresh(self)
#      93 if self._refresh_lock.acquire(block_for_refresh):
#      94     try:
# ---> 95         self._protected_refresh()
#      96     finally:
#      97         self._refresh_lock.release()
#
# File ~/miniconda3/envs/cmip6/lib/python3.9/site-packages/botocore/tokens.py:122, in DeferredRefreshableToken._protected_refresh(self)
#     118         raise
#     120 if self._is_expired():
#     121     # Fresh credentials should never be expired
# --> 122     raise TokenRetrievalError(
#     123         provider=self.method,
#     124         error_msg="Token has expired and refresh failed",
#     125     )
#
# TokenRetrievalError: Error when retrieving token from sso: Token has expired and refresh failed
